# %% [markdown]
# # Face extraction
#
# In this notebook, we take a corpus of video files, and use the [distant viewing toolkit](https://github.com/distant-viewing/dvt) to extract images of faces fro mthe collection.
